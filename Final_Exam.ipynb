# %%
import numpy as np

# Step 1: Generate a 3x4 random matrix
matrix_3x4 = np.random.randint(1, 21, size=(3, 4))  # Adjust range as needed
A = matrix_3x4[:, :3]  # Coefficient matrix (first 3 columns)
b = matrix_3x4[:, 3]   # Right-hand side vector (last column)

print("Generated 3x4 Matrix:")
print(matrix_3x4)
print("\nCoefficient Matrix (A):")
print(A)
print("\nRight-hand Side Vector (b):")
print(b)
# Out:
# Generated 3x4 Matrix:
# [[14  5  1  5]
#  [20  9 14  1]
#  [ 6  5  6 15]]
#
# Coefficient Matrix (A):
# [[14  5  1]
#  [20  9 14]
#  [ 6  5  6]]
#
# Right-hand Side Vector (b):
# [ 5  1 15]

# %% [markdown]
# **Matrix Inverse Method**

# %% [markdown]
# * Determinant should == 0

# %% [markdown]
# - - det(A) = a ( ei − fh ) − b ( di − fg ) + c ( dh − eg )
#
# Determinant is -358

# %% [markdown]
# ![462548507_2011553809321467_6567125487228805069_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# * Inverse the Matrix
# * - Cofactor & Transpose the Matrix

# %% [markdown]
# ![462566920_1104833924470577_7969314813837644072_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![462582358_2822243407978246_4478219095338561493_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# * Computing inverse is c = c / determinant

# %% [markdown]
# ![462584388_1121168632853133_3774418148449633194_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# * Multiplying Inverse by Matrix B

# %% [markdown]
# ![462563799_561185966693462_7883563372551521772_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Answer:
#
# x1 = -2.2627
# x2 = 7.6591
# x3 = -1.620

# %% [markdown]
# **Gaussian Elimination Method**

# %% [markdown]
# * Partial pivoting

# %% [markdown]
# ![462565403_879307694411552_6691392802795673174_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Forward Elimination** - Part 1

# %% [markdown]
# ![462575410_506748245037730_4515038820966507791_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![462577762_1586420185342647_7770827593520834617_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Partial Pivoting (Again)

# %% [markdown]
# ![462569965_593904406378506_4440984853984853236_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Forward Elimination** - Part 2

# %% [markdown]
# ![462583711_617613897369300_8942008249351275882_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Back Substitution**

# %% [markdown]
# ![462577031_3998307117157632_4155189674172158133_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Answer:
#
# x1 = -2.2623
# x2 = 7.660
# x3 = -1.621

# %% [markdown]
# **Verifying Answers**

# %%
# Solve using Matrix Inverse Method
try:
    A_inv = np.linalg.inv(A)  # Compute A^-1
    x_manual = np.dot(A_inv, b)  # x = A^-1 * b
    print("\nSolution using Matrix Inverse Method:")
    print(x_manual)
except np.linalg.LinAlgError:
    print("\nMatrix A is singular and cannot be inverted.")

# Solve using Gaussian Elimination
x_gaussian = np.linalg.solve(A, b)  # Direct Gaussian elimination
print("\nSolution using Gaussian Elimination (NumPy):")
print(x_gaussian)

# Verify the solution
b_check = np.dot(A, x_gaussian)  # Recompute b using A and the computed x
print("\nVerification (Ax = b):")
print(b_check)
# Out:
# Solution using Matrix Inverse Method:
# [-2.26256983  7.65921788 -1.62011173]
#
# Solution using Gaussian Elimination (NumPy):
# [-2.26256983  7.65921788 -1.62011173]
#
# Verification (Ax = b):
# [ 5.  1. 15.]
